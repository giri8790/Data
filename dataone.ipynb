# %% [markdown]
# <a href="https://colab.research.google.com/github/giri8790/Data/blob/main/dataone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('phones_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422      1690.0        1529.0         1819.0
# 1  Android         323      1803.0        1659.0         2489.0
# 2  Android         299      1803.0        1659.0         2489.0
# 3  Android         287      1803.0        1659.0         2489.0
# 4  Android        1047      1999.0           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0      10-2020
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0    brand_name                                model_name  \
# 1219        1219         Apple           iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple  iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI          nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE          nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                         x-style 35 Screen
#
#            os  popularity  best_price  lowest_price  highest_price  \
# 1219      iOS        1101     22685.0       16018.0        27900.0
# 1220      iOS         530     24600.0       21939.0        33720.0
# 1221  Android        1174      8804.0        7999.0         9999.0
# 1222  Android         752     18755.0       18500.0        19010.0
# 1223      NaN         952       907.0         785.0          944.0
#
#       sellers_amount  screen_size  memory_size  battery_size release_date
# ...

# %%
df
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#         Unnamed: 0   popularity    best_price  lowest_price  highest_price  \
# count  1224.000000  1224.000000   1224.000000    964.000000     964.000000
# mean    611.500000   612.500000   7941.206699   7716.018672    9883.410788
# std     353.482673   353.482673   8891.836260   8560.959059   11514.936818
# min       0.000000     1.000000    214.000000    198.000000     229.000000
# 25%     305.750000   306.750000   2599.750000   2399.000000    2887.000000
# 50%     611.500000   612.500000   4728.000000   4574.000000    5325.500000
# 75%     917.250000   918.250000   9323.000000   9262.250000   12673.750000
# max    1223.000000  1224.000000  56082.000000  49999.000000   69999.000000
#
#        sellers_amount  screen_size  memory_size  battery_size
# count     1224.000000  1222.000000  1112.000000   1214.000000
# mean        16.743464     5.394378    95.700059   3608.201812
# std         20.597006     1.476991   111.922576   1668.268774
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# brand_name         object
# model_name         object
# os                 object
# popularity          int64
# best_price        float64
# lowest_price      float64
# highest_price     float64
# sellers_amount      int64
# screen_size       float64
# memory_size       float64
# battery_size      float64
# release_date       object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'brand_name', 'model_name', 'os', 'popularity',
#        'best_price', 'lowest_price', 'highest_price', 'sellers_amount',
#        'screen_size', 'memory_size', 'battery_size', 'release_date'],
#       dtype='object')

# %%
pd.Categorical(df)
# Out:
# ['Unnamed: 0', 'brand_name', 'model_name', 'os', 'popularity', ..., 'sellers_amount', 'screen_size', 'memory_size', 'battery_size', 'release_date']
# Length: 13
# Categories (13, object): ['Unnamed: 0', 'battery_size', 'best_price', 'brand_name', ..., 'popularity',
#                           'release_date', 'screen_size', 'sellers_amount']

# %%
pd.Categorical(df["battery_size"])
# Out:
# [2000.0, 2000.0, 2000.0, 2000.0, 3000.0, ..., 3174.0, 3174.0, 3750.0, 4500.0, 1750.0]
# Length: 1224
# Categories (151, float64): [460.0, 600.0, 650.0, 800.0, ..., 11000.0, 13000.0, 15800.0, 18800.0]

# %%
df[0:5]
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422      1690.0        1529.0         1819.0
# 1  Android         323      1803.0        1659.0         2489.0
# 2  Android         299      1803.0        1659.0         2489.0
# 3  Android         287      1803.0        1659.0         2489.0
# 4  Android        1047      1999.0           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0      10-2020
# ...

# %%
df[::-1]
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 1223        1223  Sigma mobile                             x-style 35 Screen
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# ...          ...           ...                                           ...
# 4              4         Nokia                           1.3 1/16GB Charcoal
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1224, step=1)

# %%
df.iloc[5]
# Out:
# Unnamed: 0                      5
# brand_name                  Honor
# model_name        10 6/64GB Black
# os                        Android
# popularity                     71
# best_price                10865.0
# lowest_price              10631.0
# highest_price             11099.0
# sellers_amount                  2
# screen_size                   5.8
# memory_size                  64.0
# battery_size               3400.0
# release_date               6-2018
# Name: 5, dtype: object

# %%
df["New"]="Giri"

# %%
df['New']
# Out:
# 0       Giri
# 1       Giri
# 2       Giri
# 3       Giri
# 4       Giri
#         ...
# 1219    Giri
# 1220    Giri
# 1221    Giri
# 1222    Giri
# 1223    Giri
# Name: New, Length: 1224, dtype: object

# %%
A=[1,2,3,4,5]
pd.Series(A)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = { 'A':'A', 'title':"Giri",'Game':"Cricket"}
pd.DataFrame(d, index=['A','title','Game'])
# Out:
#        A title     Game
# A      A  Giri  Cricket
# title  A  Giri  Cricket
# Game   A  Giri  Cricket

# %%
pd.Series(d)
# Out:
# A              A
# title       Giri
# Game     Cricket
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# New                 0
# dtype: int64

# %%
df["best_price"]<1000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223     True
# Name: best_price, Length: 1224, dtype: bool

# %%
df.drop(["New"],axis=1)
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...

# %%
df.shape
# Out:
# (1224, 14)

# %%
df.rename(columns={"brand_name":"brand"})
# Out:
#       Unnamed: 0         brand                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...
